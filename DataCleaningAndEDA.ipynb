# %%
import pandas as pd

# %%
og_data = pd.read_csv("a1_data.csv")

# %%
og_data.head()
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  12016034    JD193556  01/01/2020 12:00:00 AM  018XX N WINNEBAGO AVE  1153
# 1  12220321    JD430436  01/01/2020 12:00:00 AM     091XX S DREXEL AVE  1752
# 2  12013828    JD191019  01/01/2020 12:00:00 AM   044XX S LAVERGNE AVE  0281
# 3  12019692    JD197444  01/01/2020 12:00:00 AM    032XX N LINCOLN AVE  1153
# 4  12036792    JD216459  01/01/2020 12:00:00 AM     072XX S WHIPPLE ST  1154
#
#                  Primary Type  \
# 0          DECEPTIVE PRACTICE
# 1  OFFENSE INVOLVING CHILDREN
# 2     CRIMINAL SEXUAL ASSAULT
# 3          DECEPTIVE PRACTICE
# 4          DECEPTIVE PRACTICE
#
#                                          Description Location Description  \
# 0                FINANCIAL IDENTITY THEFT OVER $ 300            APARTMENT
# 1  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER            RESIDENCE
# 2                                     NON-AGGRAVATED            APARTMENT
# ...

# %%
#data grouped & counted by crime type
crim_d = og_data.groupby('Primary Type').count()[["ID"]]
crim_d
crim_d.to_csv("byPrimaryType.csv")

# %%
crim_d2 = og_data.groupby('Description').count()[["ID"]].sort_values(["ID"], ascending=False)
crim_d2.to_csv("byDescription.csv")

# %%
crim_d3 = og_data.groupby('Location Description').count()[["ID"]]
crim_d3.to_csv("byLocationType.csv")

# %%
crim_d4 = og_data[og_data["Primary Type"] == "HOMICIDE"]
crim_d4
#og_data.groupby('Location Description').count()[["ID"]]
#crim_d3.to_csv("byLocationType.csv")
# Out:
#            ID Case Number                    Date                   Block  \
# 959     24889    JD101272  01/02/2020 02:54:00 AM  072XX S SOUTH SHORE DR
# 962     24890    JD101272  01/02/2020 03:17:00 AM  072XX S SOUTH SHORE DR
# 1221    24891    JD101694  01/02/2020 02:19:00 PM    069XX S MICHIGAN AVE
# 1394    24892    JD102066  01/02/2020 07:02:00 PM      082XX S DREXEL AVE
# 1686    25384    JD103280  01/03/2020 08:58:00 AM   018XX N SPAULDING AVE
# ...       ...         ...                     ...                     ...
# 262195  25870    JE201790  04/17/2021 06:15:00 AM  118XX S MARSHFIELD AVE
# 262573  25872    JE202539  04/18/2021 12:10:00 AM   047XX S CHAMPLAIN AVE
# 262620  25873    JE202499  04/18/2021 03:40:00 AM     027XX W FLOURNOY ST
# 262828  25874    JE203123  04/18/2021 04:39:00 PM    032XX W ROOSEVELT RD
# 262996  25875    JE203407  04/18/2021 11:52:00 PM      049XX W MADISON ST
#
#         IUCR Primary Type          Description Location Description  Arrest  \
# ...
